# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
start_url = 'https://www.imerisia.gr/oikonomia?_wrapper_format=html&page='

# %%
response = requests.get(start_url)
doc = BeautifulSoup(response.text, 'html.parser')

# %%
doc.find('div', {'class': 'square-teasers'}).find_all('article')
# Out:
# [<article class="square-teaser">
#  <a data-tb-region-item="" href="/oikonomia/73699_energeia-mikri-anodos-stis-times-ton-kaysimon-se-katheti-ptosi-fysiko-aerio-kai">
#  <div class="default-cat-date">
#  <span>ΟΙΚΟΝΟΜΙΑ</span>
#  <time datetime="2023-05-29T20:00:00+03:00">29.05.23 <span>20:00</span></time>
#  </div>
#  <h4>
#  Ενέργεια: Μικρή άνοδος στις τιμές των καυσίμων - Σε κάθετη πτώση φυσικό αέριο και ρεύμα
#  </h4>
#  <figure>
#  <img alt="" class="media__image media__element b-lazy" data-src="/sites/default/files/styles/square_medium/public/2022-05/%CF%86%CF%85%CF%83%CE%B9%CE%BA%CF%8C%20%CE%B1%CE%AD%CF%81%CE%B9%CE%BF%20%CE%B5%CF%85%CF%81%CF%89%CF%80%CE%B7.jpg?itok=yzPPXMkz" height="114" loading="lazy" src="data:image/svg+xml;charset=utf-8,%3Csvg xmlns%3D'http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg' viewBox%3D'0 0 114 114'%2F%3E" typeof="foaf:Image" width="114"/>
#  </figure>
#  <div class="default-summary">Παραμένει σε καθοδική πορεία η τιμή του φυσικού αερίου, παρασύροντας στην πορεία αυτή και τις...</div>
#  </a>
#  </article>,
#  <article class="square-teaser">
#  <a data-tb-region-item="" href="/oikonomia/trapezes/73696_hr-megaloy-tr-peiraios-ishyres-oi-prooptikes-tis-ellinikis-oikonomias">
#  <div class="default-cat-date">
#  <span>ΤΡΑΠΕΖΕΣ</span>
#  <time datetime="2023-05-29T18:33:45+03:00">29.05.23 <span>18:33</span></time>
#  </div>
#  <h4>
#  Χρ. Μεγάλου (Τρ. Πειραιώς): Ισχυρές οι προοπτικές της ελληνικής οικονομίας
#  </h4>
#  <figure>
#  <img alt="Μεγάλου" class="media__image media__element b-lazy" data-src="/sites/default/files/styles/square_medium/public/2023-04/%CE%9C%CE%B5%CE%B3%CE%AC%CE%BB%CE%BF%CF%85.jpg?itok=DKmkyhT9" height="114" loading="lazy" src="data:image/svg+xml;charset=utf-8,%3Csvg xmlns%3D'http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg' viewBox%3D'0 0 114 114'%2F%3E" typeof="foaf:Image" width="114"/>
#  </figure>
#  <div class="default-summary">Πρόσκληση στους επιχειρηματίες να μην εφησυχάσουν αλλά να προχωρήσουν σε επενδύσεις, απηύθυνε ο κ....</div>
#  </a>
#  </article>,
#  <article class="square-teaser">
#  <a data-tb-region-item="" href="/oikonomia/73668_iliakoi-thermosifones-me-diplo-systima-i-axiologisi-ton-aitiseon-pos-tha-bgoyn-oi">
#  <div class="default-cat-date">
#  <span>ΟΙΚΟΝΟΜΙΑ</span>
#  <time datetime="2023-05-29T12:52:00+03:00">29.05.23 <span>12:52</span></time>
#  </div>
#  <h4>
#  Ηλιακοί θερμοσίφωνες: Με διπλό σύστημα η αξιολόγηση των αιτήσεων - Πώς θα βγουν οι δικαιούχοι
#  </h4>
#  <figure>
#  <img alt="" class="media__image media__element b-lazy" data-src="/sites/default/files/styles/square_medium/public/2023-02/iliakos-thermosifonas.jpg?itok=rnChEobY" height="114" loading="lazy" src="data:image/svg+xml;charset=utf-8,%3Csvg xmlns%3D'http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg' viewBox%3D'0 0 114 114'%2F%3E" typeof="foaf:Image" width="114"/>
#  </figure>
#  <div class="default-summary">Με την ολοκλήρωση των αιτήσεων και την απενεργοποίηση της πλατφορμας θα καταρτιστούν 26 διακριτές...</div>
#  </a>
#  </article>,
#  <article class="square-teaser">
#  <a data-tb-region-item="" href="/oikonomia/73672_hondriko-emporio-se-anodiki-poreia-trimino">
#  <div class="default-cat-date">
#  <span>ΟΙΚΟΝΟΜΙΑ</span>
#  <time datetime="2023-05-29T12:24:32+03:00">29.05.23 <span>12:24</span></time>
#  </div>
#  <h4>
#  Χονδρικό εμπόριο: Σε ανοδική πορεία το α' τρίμηνο
#  </h4>
#  <figure>
#  <img alt="ΕΛΣΤΑΤ" class="media__image media__element b-lazy" data-src="/sites/default/files/styles/square_medium/public/2021-03/elstat_0.jpg?itok=m9yNrkR9" height="114" loading="lazy" src="data:image/svg+xml;charset=utf-8,%3Csvg xmlns%3D'http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg' viewBox%3D'0 0 114 114'%2F%3E" typeof="foaf:Image" width="114"/>
#  </figure>
#  <div class="default-summary">Τα στοιχεία της ΕΛΣΤΑΤ</div>
#  </a>
#  </article>,
#  <article class="square-teaser">
#  <a data-tb-region-item="" href="/oikonomia/73669_bambaki-posi-einai-i-eidiki-enishysi-ti-problepei-i-ypoyrgiki-apofasi">
#  <div class="default-cat-date">
#  <span>ΟΙΚΟΝΟΜΙΑ</span>
#  <time datetime="2023-05-29T11:34:22+03:00">29.05.23 <span>11:34</span></time>
#  </div>
#  <h4>
#  Βαμβάκι: Πόση είναι η ειδική ενίσχυση - Τι προβλέπει η υπουργική απόφαση
#  </h4>
#  <figure>
#  <img alt="" class="media__image media__element b-lazy" data-src="/sites/default/files/styles/square_medium/public/2023-04/vamvaki.jpg?itok=8fA_Xc4I" height="114" loading="lazy" src="data:image/svg+xml;charset=utf-8,%3Csvg xmlns%3D'http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg' viewBox%3D'0 0 114 114'%2F%3E" typeof="foaf:Image" width="114"/>
#  </figure>
#  <div class="default-summary">Αυξημένα είναι τα ποσά των ελάχιστων αποδόσεων ανά νομό</div>
#  </a>
#  </article>,
#  <article class="square-teaser">
#  <a data-tb-region-item="" href="/oikonomia/trapezes/73667_eurobank-metafora-grafeion-dioikisis-oloklironetai-i-anaplasi-toy-ktirioy">
#  <div class="default-cat-date">
#  <span>ΤΡΑΠΕΖΕΣ</span>
#  <time datetime="2023-05-29T11:17:57+03:00">29.05.23 <span>11:17</span></time>
#  </div>
#  <h4>
#  Eurobank: Μεταφορά γραφείων διοίκησης – Ολοκληρώνεται η ανάπλαση του κτηρίου στο κέντρο
#  </h4>
#  <figure>
#  <img alt="" class="media__image media__element b-lazy" data-src="/sites/default/files/styles/square_medium/public/2023-05/eurobank_grafeia.png?itok=hhRgQ8JS" height="114" loading="lazy" src="data:image/svg+xml;charset=utf-8,%3Csvg xmlns%3D'http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg' viewBox%3D'0 0 114 114'%2F%3E" typeof="foaf:Image" width="114"/>
#  </figure>
#  <div class="default-summary">Το κτήριο αναμένεται να έχει περίπου 100 θέσεις εργασίας, ενώ στην ταράτσα του το δώμα αποτελεί...</div>
#  </a>
#  </article>,
#  <article class="square-teaser">
#  <a data-tb-region-item="" href="/oikonomia/73638_hreos-nea-proori-apopliromi-dimeron-daneion-fernei-i-ependytiki-bathmida-stohos">
#  <div class="default-cat-date">
#  <span>ΟΙΚΟΝΟΜΙΑ</span>
#  <time datetime="2023-05-29T08:00:05+03:00">29.05.23 <span>08:00</span></time>
#  </div>
#  <h4>
#  Χρέος: Νέα πρόωρη αποπληρωμή διμερών δανείων φέρνει η επενδυτική βαθμίδα - Στόχος το ισχυρό σήμα στις αγορές
#  </h4>
#  <figure>
#  <img alt="Πηγή: Eurokinissi" class="media__image media__element b-lazy" data-src="/sites/default/files/styles/square_medium/public/2021-06/akropoli-simaies-ee-ellada.jpg?itok=YL_S7AiR" height="114" loading="lazy" src="data:image/svg+xml;charset=utf-8,%3Csvg xmlns%3D'http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg' viewBox%3D'0 0 114 114'%2F%3E" typeof="foaf:Image" width="114"/>
#  </figure>
#  <div class="default-summary">Οι κινήσεις του ΟΔΔΗΧ συνδέονται με την ανάκτηση της επενδυτικής βαθμίδας και στοχεύουν να στείλουν...</div>
#  </a>
#  </article>,
#  <article class="square-teaser">
#  <a data-tb-region-item="" href="/oikonomia/73645_efka-opeka-dypa-plironontai-syntaxeis-kai-epidomata-poioi-pane-tameio-ayti-tin">
#  <div class="default-cat-date">
#  <span>ΟΙΚΟΝΟΜΙΑ</span>
#  <time datetime="2023-05-29T07:37:36+03:00">29.05.23 <span>07:37</span></time>
#  </div>
#  <h4>
#  ΕΦΚΑ - ΟΠΕΚΑ - ΔΥΠΑ: Πληρώνονται συντάξεις και επιδόματα - Ποιοι πάνε ταμείο αυτή την εβδομάδα
#  </h4>
#  <figure>
#  <img alt="" class="media__image media__element b-lazy" data-src="/sites/default/files/styles/square_medium/public/2023-02/money-xrimata.jpg?itok=yfr_Si7U" height="114" loading="lazy" src="data:image/svg+xml;charset=utf-8,%3Csvg xmlns%3D'http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg' viewBox%3D'0 0 114 114'%2F%3E" typeof="foaf:Image" width="114"/>
#  </figure>
#  <div class="default-summary">Συνολικά εκτιμάται ότι θα καταβληθούν περί τα 2 δισ. ευρώ σε σχεδόν 4,9 εκατομμύρια δικαιούχους</div>
#  </a>
#  </article>,
#  <article class="square-teaser">
#  <a data-tb-region-item="" href="/oikonomia/73553_epistreptea-prokataboli-telos-hronoy-gia-ta-dikaiologitika-paratasi-stis-enstaseis">
#  <div class="default-cat-date">
#  <span>ΟΙΚΟΝΟΜΙΑ</span>
#  <time datetime="2023-05-28T09:00:00+03:00">28.05.23 <span>09:00</span></time>
#  </div>
#  <h4>
#  Επιστρεπτέα Προκαταβολή: Τέλος χρόνου για τα δικαιολογητικά - Παράταση στις ενστάσεις
#  </h4>
#  <figure>
#  <img alt="" class="media__image media__element b-lazy" data-src="/sites/default/files/styles/square_medium/public/2022-12/sales-com-1280x800.jpg?itok=QoECHISa" height="114" loading="lazy" src="data:image/svg+xml;charset=utf-8,%3Csvg xmlns%3D'http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg' viewBox%3D'0 0 114 114'%2F%3E" typeof="foaf:Image" width="114"/>
#  </figure>
#  <div class="default-summary">Οι επιχειρήσεις έχουν την ευκαιρία να γλιτώσουν από την επιστροφή ολόκληρου του ποσού του κρατικού...</div>
#  </a>
#  </article>,
#  <article class="square-teaser">
#  <a data-tb-region-item="" href="/oikonomia/trapezes/73548_stegastika-daneia-xekinoyn-oi-pliromes-tis-epidotisis-50-gia-ta-tsimpimena">
#  <div class="default-cat-date">
#  <span>ΤΡΑΠΕΖΕΣ</span>
#  <time datetime="2023-05-27T16:00:00+03:00">27.05.23 <span>16:00</span></time>
#  </div>
#  <h4>
#  Στεγαστικά δάνεια: Ξεκινούν οι πληρωμές της επιδότησης 50% για τα «τσιμπημένα» επιτόκια
#  </h4>
#  <figure>
#  <img alt="" class="media__image media__element b-lazy" data-src="/sites/default/files/styles/square_medium/public/2022-06/%CF%84%CF%81%CE%B1%CF%80%CE%B5%CE%B6%CE%B5%CF%82.jpg?itok=lV_ouZ2L" height="114" loading="lazy" src="data:image/svg+xml;charset=utf-8,%3Csvg xmlns%3D'http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg' viewBox%3D'0 0 114 114'%2F%3E" typeof="foaf:Image" width="114"/>
#  </figure>
#  <div class="default-summary">Σύμφωνα με τα στοιχεία μέχρι τις 25 Μαΐου, για το πρόγραμμα επιδότησης επιτοκίου επιλέξιμοι έχουν...</div>
#  </a>
#  </article>,
#  <article class="square-teaser">
#  <a data-tb-region-item="" href="/oikonomia/73574_forologikes-diloseis-o-enas-stoys-treis-plironei-foro-poses-ehoyn-ypoblithei">
#  <div class="default-cat-date">
#  <span>ΟΙΚΟΝΟΜΙΑ</span>
#  <time datetime="2023-05-27T09:23:58+03:00">27.05.23 <span>09:23</span></time>
#  </div>
#  <h4>
#  Φορολογικές δηλώσεις: Ο ένας στους τρεις πληρώνει φόρο - Πόσες έχουν υποβληθεί
#  </h4>
#  <figure>
#  <img alt="χρέη εφορία" class="media__image media__element b-lazy" data-src="/sites/default/files/styles/square_medium/public/2023-04/%CE%B5%CF%86%CE%BF%CF%81%CE%AF%CE%B1%20%CF%87%CF%81%CE%AD%CE%B7.jpg?itok=pZSkeGpF" height="114" loading="lazy" src="data:image/svg+xml;charset=utf-8,%3Csvg xmlns%3D'http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg' viewBox%3D'0 0 114 114'%2F%3E" typeof="foaf:Image" width="114"/>
#  </figure>
#  <div class="default-summary">Ο μέσος φόρος για 547.441 φορολογούμενους ανέρχεται σε 857 ευρώ - Οπως προκύπτει από την ανάλυση...</div>
#  </a>
#  </article>,
#  <article class="square-teaser">
#  <a data-tb-region-item="" href="/oikonomia/73552_oi-tesseris-katalytes-poy-odigoyn-pano-apo-3-tin-anaptyxi-tis-oikonomias">
#  <div class="default-cat-date">
#  <span>ΟΙΚΟΝΟΜΙΑ</span>
#  <time datetime="2023-05-27T09:00:01+03:00">27.05.23 <span>09:00</span></time>
#  </div>
#  <h4>
#  Oι τέσσερις καταλύτες που οδηγούν πάνω από 3% την ανάπτυξη της οικονομίας
#  </h4>
#  <figure>
#  <img alt="" class="media__image media__element b-lazy" data-src="/sites/default/files/styles/square_medium/public/2022-01/anaptyxi.jpg?itok=xll3fNmb" height="114" loading="lazy" src="data:image/svg+xml;charset=utf-8,%3Csvg xmlns%3D'http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg' viewBox%3D'0 0 114 114'%2F%3E" typeof="foaf:Image" width="114"/>
#  </figure>
#  <div class="default-summary">Κινητήριες δυνάμεις της ισχυρής ανόδου που καταγράφεται στην οικονομία σε συνδυασμό με την πτώση...</div>
#  </a>
#  </article>]

# %%
len(doc.find('div', {'class': 'square-teasers'}).find_all('article'))
# Out:
# 12

# %%
doc.find('div', {'class': 'square-teasers'}).find_all('article')[0]
# Out:
# <article class="square-teaser">
# <a data-tb-region-item="" href="/oikonomia/73699_energeia-mikri-anodos-stis-times-ton-kaysimon-se-katheti-ptosi-fysiko-aerio-kai">
# <div class="default-cat-date">
# <span>ΟΙΚΟΝΟΜΙΑ</span>
# <time datetime="2023-05-29T20:00:00+03:00">29.05.23 <span>20:00</span></time>
# </div>
# <h4>
# Ενέργεια: Μικρή άνοδος στις τιμές των καυσίμων - Σε κάθετη πτώση φυσικό αέριο και ρεύμα
# </h4>
# <figure>
# <img alt="" class="media__image media__element b-lazy" data-src="/sites/default/files/styles/square_medium/public/2022-05/%CF%86%CF%85%CF%83%CE%B9%CE%BA%CF%8C%20%CE%B1%CE%AD%CF%81%CE%B9%CE%BF%20%CE%B5%CF%85%CF%81%CF%89%CF%80%CE%B7.jpg?itok=yzPPXMkz" height="114" loading="lazy" src="data:image/svg+xml;charset=utf-8,%3Csvg xmlns%3D'http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg' viewBox%3D'0 0 114 114'%2F%3E" typeof="foaf:Image" width="114"/>
# </figure>
# <div class="default-summary">Παραμένει σε καθοδική πορεία η τιμή του φυσικού αερίου, παρασύροντας στην πορεία αυτή και τις...</div>
# </a>
# </article>

# %%
link = doc.find('div', {'class': 'square-teasers'}).find_all('article')[0].find('a')['href']
link
# Out:
# '/oikonomia/73699_energeia-mikri-anodos-stis-times-ton-kaysimon-se-katheti-ptosi-fysiko-aerio-kai'

# %%
main_url = 'https://www.imerisia.gr/'
link = doc.find('div', {'class': 'square-teasers'}).find_all('article')[0].find('a')['href']
article_link = main_url + link
article_link
# Out:
# 'https://www.imerisia.gr//oikonomia/73699_energeia-mikri-anodos-stis-times-ton-kaysimon-se-katheti-ptosi-fysiko-aerio-kai'

# %%
title = doc.find('div', {'class': 'square-teasers'}).find_all('article')[0].find('a').text
title
# Out:
# '\n\nΟΙΚΟΝΟΜΙΑ\n29.05.23 20:00\n\n\nΕνέργεια: Μικρή άνοδος στις τιμές των καυσίμων - Σε κάθετη πτώση φυσικό αέριο και ρεύμα\n\n\n\n\nΠαραμένει σε καθοδική πορεία η τιμή του φυσικού αερίου, παρασύροντας στην πορεία αυτή και τις...\n'

# %%
time = doc.find('div', {'class': 'square-teasers'}).find_all('article')[0].find('time').text
time
# Out:
# '29.05.23 20:00'

# %%
section = doc.find('div', {'class': 'square-teasers'}).find_all('article')[0].find('span').text
section
# Out:
# 'ΟΙΚΟΝΟΜΙΑ'

# %%
summary = doc.find('div', {'class': 'square-teasers'}).find_all('article')[0].find('div', {'class': 'default-summary'}).text
summary
# Out:
# 'Παραμένει σε καθοδική πορεία η τιμή του φυσικού αερίου, παρασύροντας στην πορεία αυτή και τις...'

# %%
main_url = 'https://www.imerisia.gr/'
stories_list = []
stories = doc.find('div', {'class': 'square-teasers'}).find_all('article')
for story in stories:
    story_dict = {}
    try: 
      link = story.find('a', {'class': 'full-link'})['href'] 
      if link.startswith("http"):
        story_dict['url'] = link
      else:
        story_dict['url'] = main_url + link
    except: 
      story_dict['url'] = ''
      pass
    try:
      title = story.find('a', {'class': 'full-link'}).text
      story_dict['title'] = title
    except:
      story_dict['title'] = ''
      pass
    try:
      time = story.find('time').text
      story_dict['time'] = time
    except:
      story_dict['time'] = ''
      pass
    try:
      section = story.find('span').text
      story_dict['section'] = section
    except:
      story_dict['section'] = ''
      pass
    try:
      summary = story.find('div', {'class': 'default-summary'}).text
      story_dict['summary'] = summary
    except:
      story_dict['summary'] = ''
      pass
    stories_list.append(story_dict)
imerisia_df = pd.DataFrame(stories_list)

# %%
imerisia_df
# Out:
#    url title            time    section  \
# 0             29.05.23 20:00  ΟΙΚΟΝΟΜΙΑ
# 1             29.05.23 18:33   ΤΡΑΠΕΖΕΣ
# 2             29.05.23 12:52  ΟΙΚΟΝΟΜΙΑ
# 3             29.05.23 12:24  ΟΙΚΟΝΟΜΙΑ
# 4             29.05.23 11:34  ΟΙΚΟΝΟΜΙΑ
# 5             29.05.23 11:17   ΤΡΑΠΕΖΕΣ
# 6             29.05.23 08:00  ΟΙΚΟΝΟΜΙΑ
# 7             29.05.23 07:37  ΟΙΚΟΝΟΜΙΑ
# 8             28.05.23 09:00  ΟΙΚΟΝΟΜΙΑ
# 9             27.05.23 16:00   ΤΡΑΠΕΖΕΣ
# 10            27.05.23 09:23  ΟΙΚΟΝΟΜΙΑ
# 11            27.05.23 09:00  ΟΙΚΟΝΟΜΙΑ
#
#                                               summary
# 0   Παραμένει σε καθοδική πορεία η τιμή του φυσικο...
# 1   Πρόσκληση στους επιχειρηματίες να μην εφησυχάσ...
# 2   Με την ολοκλήρωση των αιτήσεων και την απενεργ...
# 3                              Τα στοιχεία της ΕΛΣΤΑΤ
# 4   Αυξημένα είναι τα ποσά των ελάχιστων αποδόσεων...
# 5   Το κτήριο αναμένεται να έχει περίπου 100 θέσει...
# 6   Οι κινήσεις του ΟΔΔΗΧ συνδέονται με την ανάκτη...
# 7   Συνολικά εκτιμάται ότι θα καταβληθούν περί τα ...
# 8   Οι επιχειρήσεις έχουν την ευκαιρία να γλιτώσου...
# 9   Σύμφωνα με τα στοιχεία μέχρι τις 25 Μαΐου, για...
# 10  Ο μέσος φόρος για 547.441 φορολογούμενους ανέρ...
# 11  Κινητήριες δυνάμεις της ισχυρής ανόδου που κατ...

# %%
main_url = 'https://www.imerisia.gr/'
start_url = 'https://www.imerisia.gr/oikonomia?_wrapper_format=html&page=1'
stories_list = []
for page_num in range(0, 2):
  url = start_url + str(page_num)
  response = requests.get(url)
  doc = BeautifulSoup(response.text, 'html.parser')
  stories = doc.find('div', {'class': 'square-teasers'}).find_all('article')
  for story in stories:
      story_dict = {}
      try:
        link = story.find('a', {'class': 'full-link'})['href'] 
        if link.startswith("http"):
          story_dict['url'] = link
        else:
          story_dict['url'] = main_url + link
      except:
        story_dict['url'] = ''
        pass
      try:
        title = story.find('a', {'class': 'full-link'}).text
        story_dict['title'] = title
      except:
        story_dict['title'] = ''
        pass
      try:
        time = story.find('time').text
        story_dict['time'] = time
      except:
        story_dict['time'] = ''
        pass
      try:
        section = story.find('span').text
        story_dict['section'] = section
      except:
        story_dict['section'] = ''
        pass
      try:
        summary = story.find('div', {'class': 'default-summary'}).text
        story_dict['summary'] = summary
      except:
        story_dict['summary'] = ''
        pass
      stories_list.append(story_dict)
imerisia_df = pd.DataFrame(stories_list)

# %%
import numpy as np

# %%
imerisia_df.head(1)
# Out:
#   url title            time    section  \
# 0            02.05.23 16:24  ΟΙΚΟΝΟΜΙΑ
#
#                                              summary
# 0  Η Ρουμανία βρίσκεται ανάμεσα στους 10 κυριότερ...

# %%
imerisia_df['text'] = imerisia_df[['title', 'summary']].agg('.'.join, axis=1)
imerisia_df.loc[0, 'text']
# Out:
# '.Η Ρουμανία βρίσκεται ανάμεσα στους 10 κυριότερους εξαγωγικούς προορισμούς για τα ελληνικά προϊόντα...'

# %%
imerisia_df.dtypes
# Out:
# url        object
# title      object
# time       object
# section    object
# summary    object
# text       object
# dtype: object

# %%
imerisia_df.loc[0, 'time']
# Out:
# '02.05.23 16:24'

# %%
imerisia_df['date'] = pd.to_datetime(imerisia_df['time'], format='%d.%m.%y %H:%M')

# %%
imerisia_df.dtypes
# Out:
# url                object
# title              object
# time               object
# section            object
# summary            object
# text               object
# date       datetime64[ns]
# dtype: object

# %%
imerisia_df.head(1)
# Out:
#   url title            time    section  \
# 0            02.05.23 16:24  ΟΙΚΟΝΟΜΙΑ
#
#                                              summary  \
# 0  Η Ρουμανία βρίσκεται ανάμεσα στους 10 κυριότερ...
#
#                                                 text                date
# 0  .Η Ρουμανία βρίσκεται ανάμεσα στους 10 κυριότε... 2023-05-02 16:24:00

# %%
short_imerisia_df = imerisia_df[['date','text' ]]

# %%
short_imerisia_df.head()
# Out:
#                  date                                               text
# 0 2023-05-02 16:24:00  .Η Ρουμανία βρίσκεται ανάμεσα στους 10 κυριότε...
# 1 2023-05-02 14:52:00  .Ο δομικός πληθωρισμός, ο οποίος δεν περιλαμβά...
# 2 2023-05-02 14:31:00  .Ο βασικός παράγοντας που επηρέασε τη μείωση τ...
# 3 2023-05-02 14:05:00  .Προβλέπεται ειδικό bonus 10% για άτομα με ανα...
# 4 2023-05-02 14:04:00  .Η καταβολή της 2ης δόσης θα πραγματοποιηθεί σ...

# %%
short_imerisia_df.tail()
# Out:
#                   date                                               text
# 19 2023-04-29 08:30:00  .Την έκπληξη επιδιώκουν στο οικονομικό επιτελε...
# 20 2023-04-28 23:14:00  .Συνεργασία είναι η λέξη «κλειδί», που θα ανοί...
# 21 2023-04-28 21:52:00  .Oι μεγάλοι επενδυτές αναζητούν ευκαιρίες διαφ...
# 22 2023-04-28 21:39:00  .Η επιτακτική ανάγκη της πράσινης μετάβασης κα...
# 23 2023-04-28 21:13:00  .Η έρευνα συμπεραίνει ότι, σήμερα, εν μέσω τόσ...

# %%
short_imerisia_df.head()
# Out:
#                  date                                               text
# 0 2023-05-02 16:24:00  .Η Ρουμανία βρίσκεται ανάμεσα στους 10 κυριότε...
# 1 2023-05-02 14:52:00  .Ο δομικός πληθωρισμός, ο οποίος δεν περιλαμβά...
# 2 2023-05-02 14:31:00  .Ο βασικός παράγοντας που επηρέασε τη μείωση τ...
# 3 2023-05-02 14:05:00  .Προβλέπεται ειδικό bonus 10% για άτομα με ανα...
# 4 2023-05-02 14:04:00  .Η καταβολή της 2ης δόσης θα πραγματοποιηθεί σ...

# %%
short_imerisia_df.tail()
# Out:
#                   date                                               text
# 19 2023-04-29 08:30:00  .Την έκπληξη επιδιώκουν στο οικονομικό επιτελε...
# 20 2023-04-28 23:14:00  .Συνεργασία είναι η λέξη «κλειδί», που θα ανοί...
# 21 2023-04-28 21:52:00  .Oι μεγάλοι επενδυτές αναζητούν ευκαιρίες διαφ...
# 22 2023-04-28 21:39:00  .Η επιτακτική ανάγκη της πράσινης μετάβασης κα...
# 23 2023-04-28 21:13:00  .Η έρευνα συμπεραίνει ότι, σήμερα, εν μέσω τόσ...

# %%
short_imerisia_df['year'] = pd.DatetimeIndex(short_imerisia_df['date']).year
short_imerisia_df['month'] = pd.DatetimeIndex(short_imerisia_df['date']).month
short_imerisia_df['day'] = pd.DatetimeIndex(short_imerisia_df['date']).day
short_imerisia_df['hour'] = pd.DatetimeIndex(short_imerisia_df['date']).hour
# Out:
# <ipython-input-38-9fe27435f86c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   short_imerisia_df['year'] = pd.DatetimeIndex(short_imerisia_df['date']).year
# <ipython-input-38-9fe27435f86c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   short_imerisia_df['month'] = pd.DatetimeIndex(short_imerisia_df['date']).month
# <ipython-input-38-9fe27435f86c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   short_imerisia_df['day'] = pd.DatetimeIndex(short_imerisia_df['date']).day
# <ipython-input-38-9fe27435f86c>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   short_imerisia_df['hour'] = pd.DatetimeIndex(short_imerisia_df['date']).hour

# %%
short_imerisia_df.head()
# Out:
#                  date                                               text  \
# 0 2023-05-02 16:24:00  .Η Ρουμανία βρίσκεται ανάμεσα στους 10 κυριότε...
# 1 2023-05-02 14:52:00  .Ο δομικός πληθωρισμός, ο οποίος δεν περιλαμβά...
# 2 2023-05-02 14:31:00  .Ο βασικός παράγοντας που επηρέασε τη μείωση τ...
# 3 2023-05-02 14:05:00  .Προβλέπεται ειδικό bonus 10% για άτομα με ανα...
# 4 2023-05-02 14:04:00  .Η καταβολή της 2ης δόσης θα πραγματοποιηθεί σ...
#
#    year  month  day  hour
# 0  2023      5    2    16
# 1  2023      5    2    14
# 2  2023      5    2    14
# 3  2023      5    2    14
# 4  2023      5    2    14

# %%
short_imerisia_df['hour'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
from wordcloud import WordCloud, STOPWORDS 
import matplotlib.pyplot as plt

# %%
short_imerisia_df[short_imerisia_df['day']==30]['text']
# Out:
# 12    .Το πιθανότερο είναι η ΕΚΤ να αυξήσει τα επιτό...
# 13    .Τα στοιχεία από την εκτέλεση του προϋπολογισμ...
# 14    .Οι ληξιπρόθεσμες οφειλές προς τα νοσοκομεία α...
# Name: text, dtype: object

# %%
text = short_imerisia_df[short_imerisia_df['day']==30]['text'].str.cat(sep = ' ')

# %%
text
# Out:
# '.Το πιθανότερο είναι η ΕΚΤ να αυξήσει τα επιτόκια 25 μονάδες βάσης, ενώ υπάρχει και ενδεχόμενο να... .Τα στοιχεία από την εκτέλεση του προϋπολογισμού το πρώτο τρίμηνο του έτους δημιουργούν σοβαρές... .Οι ληξιπρόθεσμες οφειλές προς τα νοσοκομεία ανέρχονται σε πάνω από 1 δισ. ευρώ και αντί να...'

# %%
list(STOPWORDS)[0:20]
# Out:
# ['above',
#  'nor',
#  'more',
#  "you've",
#  'by',
#  'up',
#  'herself',
#  'than',
#  "i'm",
#  'i',
#  'after',
#  "he's",
#  "wasn't",
#  'also',
#  'for',
#  'doing',
#  'again',
#  'where',
#  'under',
#  'therefore']

# %%
wordcloud = WordCloud(
    width = 2000,
    height = 1000,
    background_color = 'black'
    ).generate(text) 
fig = plt.figure(
    figsize = (40, 30),
    facecolor = 'k', 
    edgecolor = 'k')
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %%
import spacy

# %%
#!python -m spacy download el_core_news_sm

# %%
nlp = spacy.load ('el_core_news_sm')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-7-761882c5349e> in <cell line: 1>()
# ----> 1 nlp = spacy.load ('el_core_news_sm')
#
# /usr/local/lib/python3.10/dist-packages/spacy/__init__.py in load(name, vocab, disable, enable, exclude, config)
#      52     RETURNS (Language): The loaded nlp object.
#      53     """
# ---> 54     return util.load_model(
#      55         name,
#      56         vocab=vocab,
#
# /usr/local/lib/python3.10/dist-packages/spacy/util.py in load_model(name, vocab, disable, enable, exclude, config)
#     447     if name in OLD_MODEL_SHORTCUTS:
#     448         raise IOError(Errors.E941.format(name=name, full=OLD_MODEL_SHORTCUTS[name]))  # type: ignore[index]
# --> 449     raise IOError(Errors.E050.format(name=name))
#     450
#     451
#
# OSError: [E050] Can't find model 'el_core_news_sm'. It doesn't seem to be a Python package or a valid path to a data directory.
